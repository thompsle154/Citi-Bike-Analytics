# %%
import pandas as pd

# %%
# 1. Create a DataFrame for the 201910-citibike-tripdata data. 
citibike_data = "JC-201910-citibike-tripdata.csv"
citibike_df = pd.read_csv(citibike_data)

# %%
citibike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           892  2019-10-01 00:20:05.0140  2019-10-01 00:34:57.3800
# 1           374  2019-10-01 00:43:48.8790  2019-10-01 00:50:03.8190
# 2           170  2019-10-01 01:35:51.8630  2019-10-01 01:38:42.5470
# 3           946  2019-10-01 02:55:53.4000  2019-10-01 03:11:40.2710
# 4           517  2019-10-01 03:10:16.1290  2019-10-01 03:18:53.6350
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3211         Newark Ave               40.721525
# 2              3194    McGinley Square               40.725340
# 3              3272       Jersey & 3rd               40.723332
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id            end station name  \
# 0               -74.038914            3280                 Astor Place
# ...

# %%
# 2. Check the datatypes of your columns
citibike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42253 entries, 0 to 42252
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             42253 non-null  int64
#  1   starttime                42253 non-null  object
#  2   stoptime                 42253 non-null  object
#  3   start station id         42253 non-null  int64
#  4   start station name       42253 non-null  object
#  5   start station latitude   42253 non-null  float64
#  6   start station longitude  42253 non-null  float64
#  7   end station id           42253 non-null  int64
#  8   end station name         42253 non-null  object
#  9   end station latitude     42253 non-null  float64
#  10  end station longitude    42253 non-null  float64
#  11  bikeid                   42253 non-null  int64
#  12  usertype                 42253 non-null  object
#  13  birth year               42253 non-null  int64
# ...

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citibike_df['tripdur_orig'] = citibike_df['tripduration']
citibike_df['tripduration'] = pd.to_datetime(citibike_df['tripduration'], unit='m')
citibike_df.head()
# Out:
#          tripduration                 starttime                  stoptime  \
# 0 1970-01-01 14:52:00  2019-10-01 00:20:05.0140  2019-10-01 00:34:57.3800
# 1 1970-01-01 06:14:00  2019-10-01 00:43:48.8790  2019-10-01 00:50:03.8190
# 2 1970-01-01 02:50:00  2019-10-01 01:35:51.8630  2019-10-01 01:38:42.5470
# 3 1970-01-01 15:46:00  2019-10-01 02:55:53.4000  2019-10-01 03:11:40.2710
# 4 1970-01-01 08:37:00  2019-10-01 03:10:16.1290  2019-10-01 03:18:53.6350
#
#    start station id start station name  start station latitude  \
# 0              3275     Columbus Drive               40.718355
# 1              3211         Newark Ave               40.721525
# 2              3194    McGinley Square               40.725340
# 3              3272       Jersey & 3rd               40.723332
# 4              3206            Hilltop               40.731169
#
#    start station longitude  end station id            end station name  \
# ...

# %%
citibike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42253 entries, 0 to 42252
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             42253 non-null  datetime64[ns]
#  1   starttime                42253 non-null  object
#  2   stoptime                 42253 non-null  object
#  3   start station id         42253 non-null  int64
#  4   start station name       42253 non-null  object
#  5   start station latitude   42253 non-null  float64
#  6   start station longitude  42253 non-null  float64
#  7   end station id           42253 non-null  int64
#  8   end station name         42253 non-null  object
#  9   end station latitude     42253 non-null  float64
#  10  end station longitude    42253 non-null  float64
#  11  bikeid                   42253 non-null  int64
#  12  usertype                 42253 non-null  object
# ...

# %%
#5. Export the Dataframe as a new CSV file without the index
citibike_df.to_csv('citibike_201910_updt.csv', index=False)
